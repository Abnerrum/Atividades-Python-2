# %% [markdown]
# 9. Comparar três números
# Peça três números. Mostre qual é o maior deles.
# Exemplo: "O maior número é 42".

# %%
# Solicitar três números ao usuário
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
num3 = float(input("Digite o terceiro número: "))

# Encontrar o maior número
maior = num1  # Suponha que o primeiro número é o maior inicialmente

if num2 > maior:
    maior = num2
if num3 > maior:
    maior = num3

# Exibir o resultado
print(f"O maior número é {maior}.")
# Out:
# Digite o primeiro número:  12
# Digite o segundo número:  34
# Digite o terceiro número:  78
# O maior número é 78.0.
